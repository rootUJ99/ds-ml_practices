# %%
import pandas as pd
df = pd.read_csv('./anime.csv').dropna()

# %%
df.tail()
# Out:
#        anime_id                                               name   genre  \
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami  Hentai
# 12290      5543                                        Under World  Hentai
# 12291      5621                     Violence Gekiga David no Hoshi  Hentai
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...  Hentai
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!  Hentai
#
#         type episodes  rating  members
# 12289    OVA        1    4.15      211
# 12290    OVA        1    4.28      183
# 12291    OVA        4    4.88      219
# 12292    OVA        1    4.98      175
# 12293  Movie        1    5.46      142

# %%
df.loc[df['genre']=='Hentai'].head()
# Out:
#        anime_id                                 name   genre type episodes  \
# 11114     11879                  Oni Chichi: Re-born  Hentai  OVA        2
# 11115     29575                   Mankitsu Happening  Hentai  OVA        4
# 11116     15843         Koiito Kinenbi The Animation  Hentai  OVA        2
# 11117     21097                  Oni Chichi: Rebuild  Hentai  OVA        3
# 11119     10779  Eroge! H mo Game mo Kaihatsu Zanmai  Hentai  OVA        6
#
#        rating  members
# 11114    7.89    14342
# 11115    7.83     8510
# 11116    7.75     6940
# 11117    7.75     9825
# 11119    7.68    20316

# %%
df.columns
# Out:
# Index(['anime_id', 'name', 'genre', 'type', 'episodes', 'rating', 'members'], dtype='object')

# %%
df.sort_values(['anime_id'] , ascending=False)
# Out:
#        anime_id                                 name  \
# 9586      34519  Mobile Suit Gakuen: G-Reco Koushien
# 2726      34514                  Pokemon Generations
# 9266      34503                    Kochinpa! Dainiki
# 10444     34490                       Sushi Azarashi
# 9991      34476   Platonic Chain: Ansatsu Jikkouchuu
# ...         ...                                  ...
# 3159          8               Beet the Vandel Buster
# 2095          7                   Witch Hunter Robin
# 214           6                               Trigun
# 152           5      Cowboy Bebop: Tengoku no Tobira
# 22            1                         Cowboy Bebop
#
#                                                    genre     type episodes  \
# 9586                                              Comedy  Special        9
# 2726              Action, Adventure, Fantasy, Game, Kids      ONA       18
# 9266                                              Comedy       TV       24
# ...

# %%
cols = df.columns
new_df = df[cols[0:2]]

# %%
new_df
# Out:
#        anime_id                                               name
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
# [12017 rows x 2 columns]
